# %%
# For subject listing in schools

import pandas 
import webbrowser
import os

# Read the dataset into a data table using Pandas
df = pandas.read_csv("subjects-offered.csv")

# Remove all primary school names if they contain the word 'Primary'
# While some schools are still left as names do not contain 'Primary' eg. 'AI TONG SCHOOL'
# They will be further removed in Excel when we merge them with the main dataset
df = df[~df['school_name'].isin(['PRIMARY'])]

# Combine all subjects from the same school into one row
df = df.groupby(["school_name"])['subject_desc'].apply(lambda x: ', '.join(x)).reset_index()

# Save combined data to a new file
df.to_csv("subjects-offered-clean.csv")

# %%
# For MOE programmes in schools

import pandas 
import webbrowser
import os

# Read the dataset into a data table using Pandas
df = pandas.read_csv("moe-programmes.csv")

# Remove all primary school names if they contain the word 'Primary'
# While some schools are still left as names do not contain 'Primary' eg. 'AI TONG SCHOOL'
# They will be further removed in Excel when we merge them with the main dataset
df = df[~df['school_name'].isin(['PRIMARY'])]

# Combine all programmes from the same school into one row
df = df.groupby(["school_name"])['moe_programme_desc'].apply(lambda x: ', '.join(x)).reset_index()

# Save combined data to a new file
df.to_csv("moe-programmes-clean.csv")
# Out:
#                            school_name  \
# 0       AHMAD IBRAHIM SECONDARY SCHOOL
# 1            ANDERSON SECONDARY SCHOOL
# 2                 ANGLICAN HIGH SCHOOL
# 3         ANGLO-CHINESE JUNIOR COLLEGE
# 4   ANGLO-CHINESE SCHOOL (INDEPENDENT)
# 5      BUKIT PANJANG GOVT. HIGH SCHOOL
# 6                 CATHOLIC HIGH SCHOOL
# 7              CATHOLIC JUNIOR COLLEGE
# 8        CEDAR GIRLS' SECONDARY SCHOOL
# 9                  CHIJ KATONG CONVENT
# 10          CHIJ SECONDARY (TOA PAYOH)
# 11     CHIJ ST. NICHOLAS GIRLS' SCHOOL
# 12      CHUNG CHENG HIGH SCHOOL (MAIN)
# 13       COMMONWEALTH SECONDARY SCHOOL
# 14              CRESCENT GIRLS' SCHOOL
# 15                  DUNMAN HIGH SCHOOL
# 16               EUNOIA JUNIOR COLLEGE
# 17               HWA CHONG INSTITUTION
# 18       JURONG PIONEER JUNIOR COLLEGE
# 19        JURONG WEST SECONDARY SCHOOL
#
#                                    moe_programme_desc
# 0                            ENHANCED MUSIC PROGRAMME
# 1   ELECTIVE PROGRAMME IN MALAY LANGUAGE FOR SECON...
# 2               LANGUAGE ELECTIVE PROGRAMME (CHINESE)
# 3   MUSIC ELECTIVE PROGRAMME, DRAMA ELECTIVE PROGR...
# 4   MUSIC ELECTIVE PROGRAMME, REGIONAL STUDIES PRO...
# 5   ART ELECTIVE PROGRAMME, ELECTIVE PROGRAMME IN ...
# 6   MUSIC ELECTIVE PROGRAMME, BICULTURAL STUDIES P...
# 7               LANGUAGE ELECTIVE PROGRAMME (ENGLISH)
# 8                          REGIONAL STUDIES PROGRAMME
# 9                              ENHANCED ART PROGRAMME
# 10                             ART ELECTIVE PROGRAMME
# 11  MUSIC ELECTIVE PROGRAMME, BICULTURAL STUDIES P...
# 12  LANGUAGE ELECTIVE PROGRAMME (CHINESE), ENHANCE...
# 13                LANGUAGE ELECTIVE PROGRAMME (TAMIL)
# 14                           MUSIC ELECTIVE PROGRAMME
# 15  LANGUAGE ELECTIVE PROGRAMME (CHINESE), MUSIC E...
# 16  MUSIC ELECTIVE PROGRAMME, BICULTURAL STUDIES P...
# 17  BICULTURAL STUDIES PROGRAMME, ART ELECTIVE PRO...
# 18  LANGUAGE ELECTIVE PROGRAMME (CHINESE), LANGUAG...
# 19                             ENHANCED ART PROGRAMME

# %%
# For CCAs in schools

import pandas 
import webbrowser
import os

# Read the dataset into a data table using Pandas
df = pandas.read_csv("co-curricular-activities-ccas.csv")

# Remove all primary school names if they contain the word 'Primary'
# While some schools are still left as names do not contain 'Primary' eg. 'AI TONG SCHOOL'
# They will be further removed in Excel when we merge them with the main dataset
df = df[~df['school_name'].isin(['PRIMARY'])]

# Combine all CCAs of the same type from the same school into one row
df = df.groupby(["school_name", 'cca_grouping_desc'])['cca_generic_name'].apply(lambda x: ', '.join(x)).reset_index()

# Pivot the table such that each type of CCA is a column in itself
#              | CLUBS & SOCIETIES | PHYSICAL SPORTS | UNIFORMED GROUPS | PERFORMING ARTS | OTHERS
# School Name  |     A, B, C       |   D, E, F       |     G, H, I      |    J, K, L      |  M, N
df = df.pivot(index='school_name', columns='cca_grouping_desc', values='cca_generic_name')

# Save combined data to a new file
df.to_csv("co-curricular-activities-ccas-clean.csv")
# Out:
# cca_grouping_desc                                                 CLUBS AND SOCIETIES  \
# school_name
# ADMIRALTY PRIMARY SCHOOL            ENGLISH LANGUAGE, DRAMA AND DEBATING, INFOCOMM...
# ADMIRALTY SECONDARY SCHOOL                                                   ROBOTICS
# AHMAD IBRAHIM PRIMARY SCHOOL                                                 ROBOTICS
# AHMAD IBRAHIM SECONDARY SCHOOL                                             GREEN CLUB
# AI TONG SCHOOL                                                               ROBOTICS
# ALEXANDRA PRIMARY SCHOOL            CHINESE CULTURE AND LANGUAGE, ROBOTICS, INFOCO...
# ANCHOR GREEN PRIMARY SCHOOL         ROBOTICS, INFOCOMM TECHNOLOGY (MEDIA PRODUCTIO...
# ANDERSON PRIMARY SCHOOL              ROBOTICS, INFOCOMM TECHNOLOGY (MEDIA PRODUCTION)
# ANDERSON SECONDARY SCHOOL           INFOCOMM TECHNOLOGY (MEDIA PRODUCTION), BIOLOG...
# ANDERSON SERANGOON JUNIOR COLLEGE   AUDIO VISUAL AID, DEBATING AND PUBLIC SPEAKING...
# ANG MO KIO PRIMARY SCHOOL                   ROBOTICS, INFOCOMM TECHNOLOGY (COMPUTING)
# ANG MO KIO SECONDARY SCHOOL                   ENVIRONMENTAL SCIENCE, AUDIO VISUAL AID
# ANGLICAN HIGH SCHOOL                DEBATING AND PUBLIC SPEAKING, ROBOTICS, INFOCO...
# ANGLO-CHINESE JUNIOR COLLEGE        LIBRARY COUNCIL, DEBATING AND PUBLIC SPEAKING,...
# ANGLO-CHINESE SCHOOL (BARKER ROAD)  INFOCOMM TECHNOLOGY (MEDIA PRODUCTION), DEBATI...
# ANGLO-CHINESE SCHOOL (JUNIOR)                   INTERNATIONAL CHESS, PHYSICAL SCIENCE
# ANGLO-CHINESE SCHOOL (PRIMARY)      INFOCOMM TECHNOLOGY (COMPUTING), AUDIO VISUAL ...
# ANGSANA PRIMARY SCHOOL              INFOCOMM TECHNOLOGY (MEDIA PRODUCTION), PHYSIC...
# ASSUMPTION ENGLISH SCHOOL                                                         NaN
# ASSUMPTION PATHWAY SCHOOL                                  ROBOTICS, AUDIO VISUAL AID
#
# cca_grouping_desc                                         OTHERS  \
# school_name
# ADMIRALTY PRIMARY SCHOOL                                     NaN
# ADMIRALTY SECONDARY SCHOOL                                   NaN
# AHMAD IBRAHIM PRIMARY SCHOOL                                 NaN
# AHMAD IBRAHIM SECONDARY SCHOOL                               NaN
# AI TONG SCHOOL                                               NaN
# ALEXANDRA PRIMARY SCHOOL                                     NaN
# ANCHOR GREEN PRIMARY SCHOOL                                  NaN
# ANDERSON PRIMARY SCHOOL                                      NaN
# ANDERSON SECONDARY SCHOOL           STUDENT LEADERSHIP (COUNCIL)
# ANDERSON SERANGOON JUNIOR COLLEGE                            NaN
# ANG MO KIO PRIMARY SCHOOL                                    NaN
# ANG MO KIO SECONDARY SCHOOL                                  NaN
# ANGLICAN HIGH SCHOOL                                         NaN
# ANGLO-CHINESE JUNIOR COLLEGE                                 NaN
# ANGLO-CHINESE SCHOOL (BARKER ROAD)                           NaN
# ANGLO-CHINESE SCHOOL (JUNIOR)                                NaN
# ANGLO-CHINESE SCHOOL (PRIMARY)                               NaN
# ANGSANA PRIMARY SCHOOL              STUDENT LEADERSHIP (PREFECT)
# ASSUMPTION ENGLISH SCHOOL                                    NaN
# ASSUMPTION PATHWAY SCHOOL                                    NaN
#
# cca_grouping_desc                                                     PHYSICAL SPORTS  \
# school_name
# ADMIRALTY PRIMARY SCHOOL            MODULAR CCA (SPORTS), FOOTBALL, TRACK AND FIEL...
# ADMIRALTY SECONDARY SCHOOL          BADMINTON, NETBALL, RUGBY, TRACK AND FIELD, WUSHU
# AHMAD IBRAHIM PRIMARY SCHOOL                     BADMINTON, VOLLEYBALL, ROPE SKIPPING
# AHMAD IBRAHIM SECONDARY SCHOOL        FOOTBALL, TRACK AND FIELD, SHOOTING, BASKETBALL
# AI TONG SCHOOL                      BADMINTON, TRACK AND FIELD, TABLE TENNIS, WUSH...
# ALEXANDRA PRIMARY SCHOOL            BASKETBALL, TRACK AND FIELD, TABLE TENNIS, BAD...
# ANCHOR GREEN PRIMARY SCHOOL                     BASKETBALL, NETBALL, WUSHU, FLOORBALL
# ANDERSON PRIMARY SCHOOL                   BADMINTON, BASKETBALL, FOOTBALL, VOLLEYBALL
# ANDERSON SECONDARY SCHOOL           BASKETBALL, NETBALL, FOOTBALL, TABLE TENNIS, W...
# ANDERSON SERANGOON JUNIOR COLLEGE   SHOOTING, BADMINTON, BASKETBALL, HOCKEY, NETBA...
# ANG MO KIO PRIMARY SCHOOL           BADMINTON, NETBALL, TRACK AND FIELD, TABLE TEN...
# ANG MO KIO SECONDARY SCHOOL         BADMINTON, BASKETBALL, NETBALL, FOOTBALL, TABL...
# ANGLICAN HIGH SCHOOL                       BADMINTON, BASKETBALL, TABLE TENNIS, WUSHU
# ANGLO-CHINESE JUNIOR COLLEGE        BADMINTON, BASKETBALL, CANOEING, CROSS COUNTRY...
# ANGLO-CHINESE SCHOOL (BARKER ROAD)  BADMINTON, BASKETBALL, HOCKEY, RUGBY, FOOTBALL...
# ANGLO-CHINESE SCHOOL (JUNIOR)       BADMINTON, RUGBY, FOOTBALL, SAILING, TABLE TEN...
# ANGLO-CHINESE SCHOOL (PRIMARY)      BOWLING, BADMINTON, BASKETBALL, RUGBY, FOOTBAL...
# ANGSANA PRIMARY SCHOOL                            BADMINTON, NETBALL, FOOTBALL, WUSHU
# ASSUMPTION ENGLISH SCHOOL             BASKETBALL, JUDO, FOOTBALL, SOFTBALL, FLOORBALL
# ASSUMPTION PATHWAY SCHOOL           BASKETBALL, SEPAKTAKRAW, FOOTBALL, FLOORBALL, ...
#
# cca_grouping_desc                                                    UNIFORMED GROUPS  \
# school_name
# ADMIRALTY PRIMARY SCHOOL                               SCOUTS, GIRL GUIDES (BROWNIES)
# ADMIRALTY SECONDARY SCHOOL          NATIONAL POLICE CADET CORPS, NATIONAL CADET CO...
# AHMAD IBRAHIM PRIMARY SCHOOL                                                   SCOUTS
# AHMAD IBRAHIM SECONDARY SCHOOL      GIRL GUIDES, NATIONAL POLICE CADET CORPS, ST J...
# AI TONG SCHOOL                                         SCOUTS, GIRL GUIDES (BROWNIES)
# ALEXANDRA PRIMARY SCHOOL                                                       SCOUTS
# ANCHOR GREEN PRIMARY SCHOOL                                                    SCOUTS
# ANDERSON PRIMARY SCHOOL                                 BOYS' BRIGADE, GIRLS' BRIGADE
# ANDERSON SECONDARY SCHOOL           GIRL GUIDES, NATIONAL POLICE CADET CORPS, NATI...
# ANDERSON SERANGOON JUNIOR COLLEGE                                                 NaN
# ANG MO KIO PRIMARY SCHOOL                                     RED CROSS YOUTH, SCOUTS
# ANG MO KIO SECONDARY SCHOOL         BOYS' BRIGADE, GIRL GUIDES, NATIONAL POLICE CA...
# ANGLICAN HIGH SCHOOL                NATIONAL CADET CORPS (LAND), SCOUTS, BOYS' BRI...
# ANGLO-CHINESE JUNIOR COLLEGE                                            BOYS' BRIGADE
# ANGLO-CHINESE SCHOOL (BARKER ROAD)  BOYS' BRIGADE, NATIONAL POLICE CADET CORPS, SC...
# ANGLO-CHINESE SCHOOL (JUNIOR)                                   BOYS' BRIGADE, SCOUTS
# ANGLO-CHINESE SCHOOL (PRIMARY)                                  BOYS' BRIGADE, SCOUTS
# ANGSANA PRIMARY SCHOOL                                        RED CROSS YOUTH, SCOUTS
# ASSUMPTION ENGLISH SCHOOL           RED CROSS YOUTH, GIRL GUIDES, NATIONAL POLICE ...
# ASSUMPTION PATHWAY SCHOOL                                                      SCOUTS
#
# cca_grouping_desc                                          VISUAL AND PERFORMING ARTS
# school_name
# ADMIRALTY PRIMARY SCHOOL            ART AND CRAFTS, CHOIR, GUITAR ENSEMBLE, CHINES...
# ADMIRALTY SECONDARY SCHOOL          MODERN DANCE, ENGLISH DRAMA, CONCERT BAND, ART...
# AHMAD IBRAHIM PRIMARY SCHOOL        ANGKLUNG/KULINTANG ENSEMBLE, CHOIR, HARMONICA ...
# AHMAD IBRAHIM SECONDARY SCHOOL      CHINESE ORCHESTRA, CHOIR, BAND - SYMPHONIC, DA...
# AI TONG SCHOOL                      ART AND CRAFTS, CHOIR, GUZHENG ENSEMBLE, CHINE...
# ALEXANDRA PRIMARY SCHOOL            HARMONICA ENSEMBLE, MODERN DANCE, ENGLISH DRAM...
# ANCHOR GREEN PRIMARY SCHOOL         CHOIR, GUZHENG ENSEMBLE, HANDBELL ENSEMBLE, MO...
# ANDERSON PRIMARY SCHOOL             MODERN DANCE, ANGKLUNG/KULINTANG ENSEMBLE, GUI...
# ANDERSON SECONDARY SCHOOL           CHOIR, CHINESE DANCE, MALAY DANCE, ENGLISH DRA...
# ANDERSON SERANGOON JUNIOR COLLEGE   CHINESE ORCHESTRA, CHOIR, GUITAR ENSEMBLE, HAR...
# ANG MO KIO PRIMARY SCHOOL           BRASS BAND, MODERN DANCE, ENGLISH DRAMA, ART A...
# ANG MO KIO SECONDARY SCHOOL         MODERN DANCE, CHOIR, MALAY DANCE, ENGLISH DRAM...
# ANGLICAN HIGH SCHOOL                CHINESE ORCHESTRA, CHOIR, GUITAR ENSEMBLE, MOD...
# ANGLO-CHINESE JUNIOR COLLEGE        CHINESE ORCHESTRA, CHOIR, STRING ENSEMBLE, ART...
# ANGLO-CHINESE SCHOOL (BARKER ROAD)  CONCERT BAND, CHINESE ORCHESTRA, CHOIR, ENGLIS...
# ANGLO-CHINESE SCHOOL (JUNIOR)       STRING ENSEMBLE, MODERN DANCE, CONCERT BAND, A...
# ANGLO-CHINESE SCHOOL (PRIMARY)      CHOIR, GUITAR ENSEMBLE, STRING ENSEMBLE, MODER...
# ANGSANA PRIMARY SCHOOL                                            CHOIR, CONCERT BAND
# ASSUMPTION ENGLISH SCHOOL                           CHOIR, MODERN DANCE, CONCERT BAND
# ASSUMPTION PATHWAY SCHOOL           PERCUSSION ENSEMBLE, MODERN DANCE, MALAY DANCE...
